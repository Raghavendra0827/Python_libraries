# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x = 'class', data= titanic_df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.countplot(y = 'class', data = titanic_df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='class'>

# %%
sns.countplot(x = 'class', data = titanic_df, hue='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.heatmap(titanic_df.corr(), annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
titanic_df.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.countplot(x='adult_male', data = titanic_df, palette = ['red','green'])
# Out:
# <AxesSubplot:xlabel='adult_male', ylabel='count'>

# %%
sns.boxplot(x='fare', data=titanic_df, hue = 'who')
# Out:
# <AxesSubplot:xlabel='fare'>

# %%
sns.boxplot(x = 'fare', y='class', data = titanic_df, hue='who')
# Out:
# <AxesSubplot:xlabel='fare', ylabel='class'>

# %%
sns.violinplot(x = 'fare', data = titanic_df)
# Out:
# <AxesSubplot:xlabel='fare'>

# %%
sns.relplot(x = 'age', y = 'fare', data = titanic_df)

# %%
sns.relplot(x = 'age', y = 'fare', data = titanic_df, kind = 'line')

# %%
import pandas as pd
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#     mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0  14.0          8         350  165      4209          12  1972       US.
# 1  31.9          4          89   71      1925          14  1980   Europe.
# 2  17.0          8         302  140      3449          11  1971       US.
# 3  15.0          8         400  150      3761          10  1971       US.
# 4  30.5          4          98   63      2051          17  1978       US.

# %%
sns.pairplot(data = df, hue = 'brand')

# %%
sns.distplot(df['mpg'] , color ='red', bins =5)
# Out:
# /Users/anipaul/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
# Question 1
# Create a scatter plot for the following data
# hp and mpg
# hp and time to 60
# hp and weightlbs
# hp and cylinders

# %%
fig, axes = plt.subplots(2,2, figsize = (20,10))
plt.subplot(2,2,1)
sns.scatterplot(x='mpg', y = 'hp', data = df)
plt.title('MPG to HP data')
plt.xlabel("Miles per Gallon")
plt.ylabel("Horsepower")

plt.subplot(2,2,2)
sns.scatterplot(x='time-to-60', y = 'hp', data = df)
plt.title('MPG to Time to 60 data')
plt.xlabel("Miles per Gallon")
plt.ylabel("Time-to-60")

plt.subplot(2,2,3)
sns.scatterplot(x='weightlbs', y = 'hp', data = df)
plt.title('MPG to Time to 60 data')
plt.xlabel("Miles per Gallon")
plt.ylabel("Time-to-60")

plt.subplot(2,2,4)
sns.scatterplot(x='cylinders', y = 'hp', data = df)
plt.title('MPG to Time to 60 data')
plt.xlabel("Miles per Gallon")
plt.ylabel("Time-to-60")
# Out:
# Text(0, 0.5, 'Time-to-60')

# %%
# Question 2
# Create a bar plot for the following data
# cylinders and hp,
# cylinders and mpg
# cylinders and weight
# year and time-to-60
# year and mpg
# year and hp


fig,axes=plt.subplots(3,2,figsize = (20,10))
plt.subplot(3,2,1)
sns.barplot(x='cylinders',y='hp',data = df)
plt.title('Cylinders to HP Data')
plt.xlabel('Cyclinders')
plt.xlabel('Horse power')

plt.subplot(3,2,2)
sns.barplot(x='cylinders',y='mpg',data = df)
plt.title('Cylinders to Mpg Data')
plt.xlabel('Cylinders')
plt.xlabel('Miles per gallon')


plt.subplot(3,2,3)
sns.barplot(x='cylinders',y='weightlbs',data = df)
plt.title('Cylinders to Weight Data')
plt.ylabel('Weight in lbs')
plt.xlabel('Cylinders')


plt.subplot(3,2,4)
sns.barplot(x='year',y='time-to-60',data = df)
plt.title('Year to Time-to-60 Data')
plt.xlabel('Year')
plt.xlabel('Time-to-60')


plt.subplot(3,2,5)
sns.barplot(x='year',y='mpg',data = df)
plt.title('Year to MPGData')
plt.xlabel('Year')
plt.xlabel('MPG')

plt.subplot(3,2,6)
sns.barplot(x='year',y='hp',data = df)
plt.title('Year to HP Data')
plt.xlabel('Year')
plt.xlabel('Horse power')
# Out:
# Text(0.5, 0, 'Horse power')

# %%
# Out:
# Text(0, 0.5, 'Horse Power')
